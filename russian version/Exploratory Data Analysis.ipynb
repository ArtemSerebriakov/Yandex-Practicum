# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Заполнение-пропусков" data-toc-modified-id="Заполнение-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Заполнение пропусков</a></span></li><li><span><a href="#check-3.1" data-toc-modified-id="check-3.1-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>check 3.1</a></span></li><li><span><a href="#Проверка-данных-на-аномалии-и-исправления" data-toc-modified-id="Проверка-данных-на-аномалии-и-исправления-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Проверка данных на аномалии и исправления</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Удаление-дубликатов" data-toc-modified-id="Удаление-дубликатов-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Удаление дубликатов</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров-объектов" data-toc-modified-id="Изучение-параметров-объектов-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров объектов</a></span></li><li><span><a href="#Изучение-скорости-продажи-квартир" data-toc-modified-id="Изучение-скорости-продажи-квартир-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение скорости продажи квартир</a></span></li><li><span><a href="#Изучение-влияния-различных-параметров-на-цену-объекта" data-toc-modified-id="Изучение-влияния-различных-параметров-на-цену-объекта-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучение влияния различных параметров на цену объекта</a></span></li><li><span><a href="#Нахождение-стоимости-квартир-в-топ-10-самых-популярных-населенных-пунктах" data-toc-modified-id="Нахождение-стоимости-квартир-в-топ-10-самых-популярных-населенных-пунктах-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Нахождение стоимости квартир в топ-10 самых популярных населенных пунктах</a></span></li><li><span><a href="#Нахождение-зависимости-цены-объекта-от-расстояния-до-центра-города" data-toc-modified-id="Нахождение-зависимости-цены-объекта-от-расстояния-до-центра-города-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Нахождение зависимости цены объекта от расстояния до центра города</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Бонус" data-toc-modified-id="Бонус-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Бонус</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Артём :)
#
# Спасибо за работу на проекте
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны хорошо, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# стоит обратить внимание на пару комментариев к третьей версии

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Артём :) Спасибо за исправления
#
# Критические ❌ комментарии
#
# + проверить корректность заполнения пропусков синтетическими данными
# + настроить условия фильтрации аномалий и редкостей, некоторые смягчить
# + пересчитать скорость продаж
# + исправить графики и расчет в п. 4.3 (нулевые заглушки)
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Артём :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, да и самому будет легче  идти к главной цели проекта

# %% [markdown]
# <div class="alert alert-info">
# План работы:
# <br>1.Изучить общую информацию из датафрейма.
# <br>2.Найти и изучить пропущенные значения в столбцах.
# <br>3.Рассмотреть типы данных в каждом столбце.
# <br>4.Устранить неявные дубликаты.
# <br>5.Найти и обработать аномалии.
# <br>6.Добавьте в таблицу новые столбцы, нужные для дальнейшего исследования.
# <br>7.Изучить параметры объектов.
# <br>8.Изучить, как быстро продавались квартиры.
# <br>9.Изучить, какие факторы больше всего влияют на общую (полную) стоимость объекта.
# <br>10.Выделить населённые пункты с самой высокой и низкой стоимостью квадратного метра среди десяти с наибольшим числом объявлений.
# <br>11.Исследовать, как стоимость объектов зависит от расстояния до центра города.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принято

# %% [markdown]
# ## Изучение данных из файла

# %%
#pip install nb_black

# %%
#%load_ext nb_black

# %%
import pandas as pd

# %%
df = pd.read_csv("/datasets/real_estate_data.csv", sep="\t")

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.shape
# Out:
# (23699, 22)

# %% [markdown]
# Из полученной информации видно, что пропущены значения в столбцах `ceiling_height`, `floors_total`, `living_area`, `is_apartment`, `kitchen_area`, `balcony`, `locality_name`, `airports_nearest`, `cityCenters_nearest`, `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest` и `days_exposition`.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит выполнить пункт из брифа проекта
#
# Шаг 1. Откройте файл с данными и изучите общую информацию
# + __Постройте общую гистограмму для всех столбцов таблицы. Например, для датафрейма data это можно сделать командой data.hist(figsize=(15, 20)).__

# %% [markdown]
# <div class="alert alert-info">
# Построим гистограмму для всех столбцов таблицы в порядке убывания количества пропусков.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Не понял, зачем нужна строчка df.isna().mean()*100 и .to_frame() в примере.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />лучше один раз увидеть, чем 100 раз услышать :)
#
# в первом случае серия, во втором датафрейм

# %% [markdown]
# <div class="alert alert-info">
# Про .to_frame() понял, а на 100 мы среднее умножаем, чтобы в процентах показатели вывести?
# </div>

# %%
# check
df.isna().mean() * 100
# Out:
# total_images             0.000000
# last_price               0.000000
# total_area               0.000000
# first_day_exposition     0.000000
# rooms                    0.000000
# ceiling_height          38.799105
# floors_total             0.362885
# living_area              8.029875
# floor                    0.000000
# is_apartment            88.290645
# studio                   0.000000
# open_plan                0.000000
# kitchen_area             9.612220
# balcony                 48.605426
# locality_name            0.206760
# airports_nearest        23.384953
# cityCenters_nearest     23.287902
# parks_around3000        23.283683
# parks_nearest           65.909954
# ponds_around3000        23.283683
# ponds_nearest           61.559559
# days_exposition         13.422507
# dtype: float64

# %%
# check
(df.isna().mean() * 100).to_frame()
# Out:
#                               0
# total_images           0.000000
# last_price             0.000000
# total_area             0.000000
# first_day_exposition   0.000000
# rooms                  0.000000
# ceiling_height        38.799105
# floors_total           0.362885
# living_area            8.029875
# floor                  0.000000
# is_apartment          88.290645
# studio                 0.000000
# open_plan              0.000000
# kitchen_area           9.612220
# balcony               48.605426
# locality_name          0.206760
# airports_nearest      23.384953
# cityCenters_nearest   23.287902
# parks_around3000      23.283683
# parks_nearest         65.909954
# ponds_around3000      23.283683
# ponds_nearest         61.559559
# days_exposition       13.422507

# %%
# check
# пропущенные значения бары


def pass_value_barh(df):
    (
        (df.isna().mean() * 100)
        .to_frame()
        .rename(columns={0: "space"})
        .query("space > 0")
        .sort_values(by="space", ascending=True)
        .plot(kind="barh", figsize=(19, 6), rot=-5, legend=False, fontsize=16)
        .set_title(
            "Гистограмма для столбцов таблицы" + "\n", fontsize=22, color="SteelBlue"
        )
    )

# %%
pass_value_barh(df)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Заполнение пропусков

# %% [markdown]
# Определим тип пропущенных значений.

# %%
df[df["ceiling_height"].isna()].head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 5            10   2890000.0        30.4  2018-09-10T00:00:00      1
# 6             6   3700000.0        37.3  2017-11-02T00:00:00      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 5             NaN          12.0         14.4      5          NaN  ...
# 6             NaN          26.0         10.6      6          NaN  ...
#
#    kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
df[df["floors_total"].isna()].head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237              4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457              4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671              4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757             5   3600000.0        39.0  2017-04-22T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 186              NaN           NaN        30.80      4          NaN  ...
# 237              NaN           NaN        20.75      1          NaN  ...
# 457              NaN           NaN        38.40     12          NaN  ...
# 671              NaN           NaN        47.10      8          NaN  ...
# 1757             NaN           NaN          NaN      9          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df[df["locality_name"].isna()].head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1097             3   8600000.0        81.7  2016-04-15T00:00:00      3
# 2033             6   5398000.0        80.0  2017-05-30T00:00:00      3
# 2603            20   3351765.0        42.7  2015-09-20T00:00:00      1
# 2632             2   5130593.0        62.4  2015-10-11T00:00:00      2
# 3574            10   4200000.0        46.5  2016-05-28T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1097            3.55           5.0         50.8      2          NaN  ...
# 2033             NaN           4.0         42.6      2          NaN  ...
# 2603             NaN          24.0         15.6      3          NaN  ...
# 2632             NaN          24.0         33.1     21          NaN  ...
# 3574             NaN           5.0         30.8      5          NaN  ...
#
#       kitchen_area  balcony  locality_name  airports_nearest  \
# ...

# %%
df[df["days_exposition"].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0  2019-03-07T00:00:00      3
# 7              5   7915000.0        71.6  2019-04-18T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
# 45            17   5200000.0        50.6  2018-12-02T00:00:00      2
# 46            17   6600000.0        52.1  2019-01-31T00:00:00      2
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             2.70          16.0         51.0      8          NaN  ...
# 7              NaN          24.0          NaN     22          NaN  ...
# 44             NaN          22.0          NaN      3          NaN  ...
# 45            2.65           9.0         30.3      7          NaN  ...
# 46            2.60          24.0         29.7      9          NaN  ...
#
#     kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Получаем, что в рассматриваемых столбцах содержатся пропущенные данные типа `NaN`.

# %% [markdown]
# Найдем количество пропусков в этих столбцах, посчитаем, какую долю составляют пропущенные значения в каждом из столбцов с пропусками и получим статистики распределения столбцов.

# %%
df["floors_total"].isna().sum()
# Out:
# 86

# %%
df["floors_total"].isna().mean()
# Out:
# 0.0036288450989493226

# %%
df["floors_total"].describe()
# Out:
# count    23613.000000
# mean        10.673824
# std          6.597173
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# В данном случае мы не можем заменить пропущенные значения медианными как раньше, так как у нас может получится ситуация, когда значение столбца `floor` окажется больше медианного значения `floors_total`, поэтому заменим пропуски данными из `floor`.

# %%
df.loc[df["floors_total"].isna(), "floors_total"] = df["floor"]

# %%
df["floors_total"].isna().sum()
# Out:
# 0

# %% [markdown]
# Замена пропусков в `floors_total` прошла успешно.

# %%
df.loc[df["living_area"].isna() | df["kitchen_area"].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 7                 5   7915000.0       71.60  2019-04-18T00:00:00      2
# 30               12   2200000.0       32.80  2018-02-19T00:00:00      1
# 37               10   1990000.0       45.80  2017-10-28T00:00:00      2
# 44               13   5350000.0       40.00  2018-11-18T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23663            12   6400000.0       88.00  2018-01-12T00:00:00      4
# 23670             9   2450000.0       45.60  2018-02-08T00:00:00      1
# 23679             0   2500000.0       35.00  2017-12-08T00:00:00      1
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df["living_area"].isna().sum()
# Out:
# 1903

# %%
df["living_area"].isna().mean()
# Out:
# 0.08029874678256467

# %%
df["living_area"].describe()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
df["is_apartment"].isna().sum()
# Out:
# 20924

# %%
df["is_apartment"].isna().mean()
# Out:
# 0.8829064517490189

# %% [markdown]
# Если значение в столбце `is_apartment` не определено, то будем считать, что оно `False`.

# %%
df.loc[(df["is_apartment"].isna()), "is_apartment"] = False

# %%
df["is_apartment"].isna().sum()
# Out:
# 0

# %% [markdown]
# Замена выполнена успешно.

# %%
df["kitchen_area"].isna().sum()
# Out:
# 2278

# %%
df["kitchen_area"].isna().mean()
# Out:
# 0.09612219924891345

# %%
df["kitchen_area"].describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
len(df.loc[(df["living_area"].isna()) & (df["kitchen_area"].isna())])
# Out:
# 1464

# %% [markdown]
# <div class="alert alert-info">
# В строчках, где значения одновременно пропущенны в столбцах `living_area` и `kitchen_area`, в столбец `living_area` занесем значение, равное 0.89 * `total_area`, а в `kitchen_area` - ноль. В таком случае мы предполагаем, что рассматривается квартира-студия, при этом считаем, что 0.11 * `total_area` - площадь других комнат в квартире (коридоры, сан.узлы, балконы).
# </div>

# %%
len(df.loc[df["kitchen_area"] == 0.0])
# Out:
# 0

# %%
df.loc[(df["living_area"].isna()) & (df["kitchen_area"].isna()), "kitchen_area"] = 0.0

# %%
len(df.loc[df["kitchen_area"] == 0.0])
# Out:
# 1464

# %%
len(df.loc[(df["living_area"].isna()) & (df["kitchen_area"] == 0.0)])
# Out:
# 1464

# %%
df.loc[(df["living_area"].isna()) & (df["kitchen_area"] == 0.0), "living_area"] = (
    0.89 * df["total_area"]
)

# %%
len(df.loc[(df["living_area"].isna()) & (df["kitchen_area"] == 0.0)])
# Out:
# 0

# %%
df["living_area"].isna().sum()
# Out:
# 439

# %%
df["kitchen_area"].isna().sum()
# Out:
# 814

# %% [markdown]
# <div class="alert alert-info">
# Как видим, строчек с пропущенными значенями в столбцах `kitchen_area` или `living_area` не так много, и эти пропуски не исказят результаты будущего анализа датафрейма, поэтому можем их оставить.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         df.loc[(df["living_area"].isna()), "living_area"] = (
#             0.89 * df["total_area"] - df["kitchen_area"]
#         )
#
#         df.loc[(df["kitchen_area"].isna()), "kitchen_area"] = (
#             0.89 * df["total_area"] - df["living_area"]
#         )
#
#
# кодом мы создаем записи с отрицательной площадью ...
#
# нет необходимости заполнять аномалиями пропуски в колонках, пока мы с ними можем жить в мире :)

# %% [markdown]
# ### check 3.1

# %%
# check
df[df["living_area"] <0]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
# check
df[df["kitchen_area"] < 0]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Самое важное — приобрести навык__ — любая замена пропусков очень трудоемка по ресурсам, т.к. приходится искать оптимальный вариант и если можно работать, имея пропуски в данных — лучше отказаться от заполнения
#
# но есть другие случаи, когда пропуски заполнять обязательно нужно, на проекте по стат. анализу — внимательно посмотри на пропуски в данных в объединенной таблице (кроме даты оттока клиентов)
#
# в итоге каждый раз мы вынуждены будем принимать решение — заполнять пропуски и как заполнять, или оставлять

# %%
df["kitchen_area"].isna().sum()
# Out:
# 814

# %% [markdown]
# Замена выполнена успешно.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %%
data = df.copy()
data[data['total_area']*0.9 <= (
    data ['living_area']+data ['kitchen_area'])][['total_area'
                                   ,'living_area','kitchen_area']]
# Out:
#        total_area  living_area  kitchen_area
# 41           74.0         59.0          12.0
# 171          49.0         38.0          10.0
# 184          30.2         26.1           6.2
# 220          37.0         28.0           9.0
# 319          59.7         47.4           6.4
# ...           ...          ...           ...
# 23216       114.0         90.2          16.0
# 23297        48.2         42.2           6.0
# 23328        54.0         40.0          10.0
# 23521        65.0         44.0          15.3
# 23680        59.0         52.0           7.0
#
# [475 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-dange
#             r">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />в итоге у нас 3182 аномальных записи, алгоритм заполнения стоит поменять или отменить

# %% [markdown]
# <div class="alert alert-info">
# Как видим, в нашем датафрейме еще остались строчки, в которых:  total_area*0.9 <= (living_area + kitchen_area).
# Их немного, поэтому можно их не учитывать в дальнейшем исследовании.
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23260 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          22885 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df["balcony"].isna().sum()
# Out:
# 11519

# %%
df["balcony"].isna().mean()
# Out:
# 0.4860542638929913

# %%
df["balcony"].describe()
# Out:
# count    12180.000000
# mean         1.150082
# std          1.071300
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          5.000000
# Name: balcony, dtype: float64

# %% [markdown]
# Считаем, что если значение балкона не определено, то квартира просто его не имеет.

# %%
df.loc[(df["balcony"].isna()), "balcony"] = 0

# %%
df["balcony"].isna().sum()
# Out:
# 0

# %% [markdown]
# Замена выполнена успешно.

# %%
df["locality_name"].isna().sum()
# Out:
# 49

# %%
df["locality_name"].isna().mean()
# Out:
# 0.002067597788936242

# %% [markdown]
# Пропуски в столбце `locality_name` встречаются крайне редко, поэтому можем удалить строчки с неопределенным месторасположением.

# %%
df = df.loc[~df["locality_name"].isna()]

# %%
df["locality_name"].isna().sum()
# Out:
# 0

# %% [markdown]
# Удаление прошло успешно.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />верное решение

# %%
df["airports_nearest"].isna().sum()
# Out:
# 5534

# %%
df["airports_nearest"].isna().mean()
# Out:
# 0.23399577167019028

# %%
df["airports_nearest"].describe()
# Out:
# count    18116.000000
# mean     28803.225878
# std      12637.314144
# min          0.000000
# 25%      18575.750000
# 50%      26756.500000
# 75%      37294.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
df["cityCenters_nearest"].isna().sum()
# Out:
# 5511

# %%
df["cityCenters_nearest"].isna().mean()
# Out:
# 0.2330232558139535

# %%
df["cityCenters_nearest"].describe()
# Out:
# count    18139.000000
# mean     14197.860742
# std       8606.830295
# min        181.000000
# 25%       9241.000000
# 50%      13105.000000
# 75%      16293.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %%
df["parks_around3000"].isna().sum()
# Out:
# 5510

# %%
df["parks_around3000"].isna().mean()
# Out:
# 0.23298097251585623

# %%
df["parks_around3000"].describe()
# Out:
# count    18140.000000
# mean         0.611577
# std          0.802003
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: parks_around3000, dtype: float64

# %%
df["parks_nearest"].isna().sum()
# Out:
# 15586

# %%
df["parks_nearest"].isna().mean()
# Out:
# 0.6590274841437632

# %%
df["parks_nearest"].describe()
# Out:
# count    8064.000000
# mean      490.830729
# std       342.554386
# min         1.000000
# 25%       288.000000
# 50%       454.500000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
df["ponds_around3000"].isna().sum()
# Out:
# 5510

# %%
df["ponds_around3000"].isna().mean()
# Out:
# 0.23298097251585623

# %%
df["ponds_around3000"].describe()
# Out:
# count    18140.000000
# mean         0.769680
# std          0.937948
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: ponds_around3000, dtype: float64

# %%
df["ponds_nearest"].isna().sum()
# Out:
# 14565

# %%
df["ponds_nearest"].isna().mean()
# Out:
# 0.6158562367864694

# %%
df["ponds_nearest"].describe()
# Out:
# count    9085.000000
# mean      518.059879
# std       277.841733
# min        13.000000
# 25%       293.000000
# 50%       502.000000
# 75%       730.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# В столбцах `airports_nearest`, `cityCenters_nearest`, `parks_nearest`, `ponds_nearest`, в которых описываются количественные переменные, заменим пропуски медианными значениями, так как они наименее чувствительны к выбросам в данных.

# %%
airports_nearest_median = df["airports_nearest"].median()

# %%
airports_nearest_median
# Out:
# 26756.5

# %%
df.loc[df["airports_nearest"].isna(), "airports_nearest"] = airports_nearest_median

# %%
df["airports_nearest"].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-info">
# Найдем распределение пропусков в столбце `cityCenters_nearest` по городам.
# </div>

# %%
df.loc[df["cityCenters_nearest"].isna()].groupby("locality_name")["locality_name"].agg(
    ["count"]
).sort_values("count", ascending=False).query('locality_name=="Санкт-Петербург"')
# Out:
#                  count
# locality_name
# Санкт-Петербург     61

# %%
df.loc[df["cityCenters_nearest"].isna()].groupby("locality_name")["locality_name"].agg(
    ["count"]
).sort_values("count", ascending=False)
# Out:
#                                        count
# locality_name
# посёлок Мурино                           522
# Всеволожск                               398
# Гатчина                                  307
# деревня Кудрово                          299
# Выборг                                   237
# ...                                      ...
# поселок городского типа Большая Ижора      1
# поселок Цвылёво                            1
# деревня Трубников Бор                      1
# поселок Усть-Луга                          1
# село Шум                                   1
#
# [345 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-info">
# Так как для дальнейшего анализа нам необходима информации о расстоянии до центра только для Санкт-Петербурга, то заполним пропуски в столбце `cityCenters_nearest` только для него.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %%
cityCenters_nearest_median = df.query('locality_name=="Санкт-Петербург"')[
    "cityCenters_nearest"
].median()

# %%
cityCenters_nearest_median
# Out:
# 12244.5

# %%
df[
    (df["locality_name"] == "Санкт-Петербург") & (df["cityCenters_nearest"].isna())
] = cityCenters_nearest_median

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не изучено распределение пропусков по городам до заполнения значений в ['city_сenters_nearest']
#
# Стоит оценить степень влияния на дальнейший анализ (будут мешать или нет)

# %%
df[(df["locality_name"] == "Санкт-Петербург") & (df["cityCenters_nearest"].isna())][
    "cityCenters_nearest"
].count()
# Out:
# 0

# %%
df["ceiling_height"].isna().sum()
# Out:
# 9130

# %%
df["ceiling_height"].isna().mean()
# Out:
# 0.386046511627907

# %%
df["ceiling_height"].describe()
# Out:
# count    14520.000000
# mean        54.199590
# std        791.818606
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max      12244.500000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении медианой необходимо четко отслеживать изменение других статистик: среднее, дисперсию
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# <div class="alert alert-info">
# Так как столбец `ceiling_height` описывает количественную величину, то можем заменить пропуски в нем медианным значением. При этом стоит рассмотреть районность высоты потолков, так как в современных районах Санкт-Петербурга высота потолков будет ожидаема ниже, чем в исторических, и мы увидим, что заполнение подобного объема пропусков медианой или средним значением общей выборки «размажет» это отличительное свойство объектов недвижимости в центре Санкт-Петербурга.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Добавим в таблицу столбец `center_distance_km`, в котором будет храниться расстояние до центра в километрах.
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  float64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  float64
#  5   ceiling_height        14520 non-null  float64
#  6   floors_total          23650 non-null  float64
#  7   living_area           23214 non-null  float64
#  8   floor                 23650 non-null  float64
#  9   is_apartment          23650 non-null  object
#  10  studio                23650 non-null  object
#  11  open_plan             23650 non-null  object
#  12  kitchen_area          22843 non-null  float64
#  13  balcony               23650 non-null  float64
# ...

# %%
df.query('locality_name=="Санкт-Петербург"')["cityCenters_nearest"].isna().sum()
# Out:
# 0

# %%
def get_km(row):
    if row["locality_name"] == "Санкт-Петербург":
        return round(row["cityCenters_nearest"] / 1000)
    else:
        return 0.0

# %%
df["center_distance_km"] = df.apply(get_km, axis=1)

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0      108.00  2019-03-07T00:00:00    3.0
# 1           7.0   3350000.0       40.40  2018-12-04T00:00:00    1.0
# 2          10.0   5196000.0       56.00  2015-08-20T00:00:00    2.0
# 3           0.0  64900000.0      159.00  2015-07-24T00:00:00    3.0
# 4           2.0  10000000.0      100.00  2018-06-19T00:00:00    2.0
# 5          10.0   2890000.0       30.40  2018-09-10T00:00:00    1.0
# 6           6.0   3700000.0       37.30  2017-11-02T00:00:00    1.0
# 7           5.0   7915000.0       71.60  2019-04-18T00:00:00    2.0
# 8          20.0   2900000.0       33.16  2018-05-23T00:00:00    1.0
# 9          18.0   5400000.0       61.00  2017-02-26T00:00:00    3.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ... balcony  \
# 0            2.70          16.0        51.00    8.0        False  ...     0.0
# ...

# %%
df["center_distance_km"] = df["center_distance_km"].astype("int")

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0      108.00  2019-03-07T00:00:00    3.0
# 1           7.0   3350000.0       40.40  2018-12-04T00:00:00    1.0
# 2          10.0   5196000.0       56.00  2015-08-20T00:00:00    2.0
# 3           0.0  64900000.0      159.00  2015-07-24T00:00:00    3.0
# 4           2.0  10000000.0      100.00  2018-06-19T00:00:00    2.0
# 5          10.0   2890000.0       30.40  2018-09-10T00:00:00    1.0
# 6           6.0   3700000.0       37.30  2017-11-02T00:00:00    1.0
# 7           5.0   7915000.0       71.60  2019-04-18T00:00:00    2.0
# 8          20.0   2900000.0       33.16  2018-05-23T00:00:00    1.0
# 9          18.0   5400000.0       61.00  2017-02-26T00:00:00    3.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ... balcony  \
# 0            2.70          16.0        51.00    8.0        False  ...     0.0
# ...

# %%
df.plot(
    x="center_distance_km",
    y="last_price",
    style="o",
    grid=True,
    alpha=0.2,
    ylim=(0, 3 * 100000000),
    xlim=(0, 40),
)
# Out:
# <AxesSubplot:xlabel='center_distance_km'>

# %% [markdown]
# По скачку стоимости квартир можно сделать вывод, что центральная зона заканчивается на расстоянии примерно 6.5 км от центра.

# %%
ceiling_height_median_centre = df.query("center_distance_km<=6.5")[
    "ceiling_height"
].median()

# %%
ceiling_height_median_centre
# Out:
# 2.7

# %%
ceiling_height_median_not_centre = df.query("center_distance_km>6.5")[
    "ceiling_height"
].median()

# %%
ceiling_height_median_not_centre
# Out:
# 2.61

# %% [markdown]
# Заменим пропуски в столбце `ceiling_height` медианными значением.

# %%
df.loc[
    (df["center_distance_km"] <= 6.5) & (df["ceiling_height"].isna()), "ceiling_height"
] = ceiling_height_median_centre

# %%
df.loc[
    (df["center_distance_km"] > 6.5) & (df["ceiling_height"].isna()), "ceiling_height"
] = ceiling_height_median_not_centre

# %%
df["ceiling_height"].isna().sum()
# Out:
# 0

# %%
df.query("ceiling_height==@ceiling_height_median_centre").head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0           20.0  13000000.0      108.00  2019-03-07T00:00:00    3.0
# 1            7.0   3350000.0       40.40  2018-12-04T00:00:00    1.0
# 5           10.0   2890000.0       30.40  2018-09-10T00:00:00    1.0
# 6            6.0   3700000.0       37.30  2017-11-02T00:00:00    1.0
# 8           20.0   2900000.0       33.16  2018-05-23T00:00:00    1.0
# 11           9.0   3300000.0       44.00  2018-08-27T00:00:00    2.0
# 12          10.0   3890000.0       54.00  2016-06-30T00:00:00    2.0
# 14           1.0   4400000.0       36.00  2016-06-23T00:00:00    1.0
# 20          12.0   6120000.0       80.00  2017-09-28T00:00:00    3.0
# 24           8.0   6500000.0       97.20  2015-10-31T00:00:00    2.0
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0              2.7          16.0        51.00    8.0        False  ...
# ...

# %%
df.query("ceiling_height==@ceiling_height_median_not_centre").head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 2           10.0   5196000.0        56.0  2015-08-20T00:00:00    2.0
# 3            0.0  64900000.0       159.0  2015-07-24T00:00:00    3.0
# 7            5.0   7915000.0        71.6  2019-04-18T00:00:00    2.0
# 15          16.0   4650000.0        39.0  2017-11-18T00:00:00    1.0
# 17           6.0   4180000.0        36.0  2016-09-09T00:00:00    1.0
# 21          13.0   3200000.0        31.6  2018-03-14T00:00:00    1.0
# 26           6.0   4050000.0        60.0  2017-04-28T00:00:00    4.0
# 29           9.0   8600000.0       100.0  2016-04-09T00:00:00    3.0
# 32           7.0   4990000.0        60.0  2016-05-22T00:00:00    3.0
# 36          13.0   3790000.0        45.0  2017-01-25T00:00:00    2.0
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 2             2.61           5.0        34.30    4.0        False  ...
# ...

# %% [markdown]
# Как видим, замена строк с пропущенными значениями медианными прошла успешно.

# %%
parks_nearest_median = df["parks_nearest"].median()

# %%
parks_nearest_median
# Out:
# 456.0

# %%
df.loc[df["parks_nearest"].isna(), "parks_nearest"] = parks_nearest_median

# %%
df["parks_nearest"].isna().sum()
# Out:
# 0

# %%
ponds_nearest_median = df["ponds_nearest"].median()

# %%
ponds_nearest_median
# Out:
# 504.0

# %%
df.loc[df["ponds_nearest"].isna(), "ponds_nearest"] = ponds_nearest_median

# %%
df["ponds_nearest"].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-info">
# Пропуски в столбце 'days_exposition` говорят нам, что квартиры не проданы, поэтому оставим их.
# </div>

# %% [markdown]
# <div class="alert alert-d
#             anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пропуски в ['days_exposition'] говорят нам, что квартиры еще не проданы..., неверно терять столь важный признак, → оставляем пропуски

# %%
df["ponds_around3000"].describe()
# Out:
# count    18201.000000
# mean        41.804104
# std        707.643262
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max      12244.500000
# Name: ponds_around3000, dtype: float64

# %%
df["parks_around3000"].describe()
# Out:
# count    18201.000000
# mean        41.646530
# std        707.652233
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max      12244.500000
# Name: parks_around3000, dtype: float64

# %% [markdown]
# Видим, что медианы в столбцах `ponds_around3000` и `parks_around3000` принимают целые значения, поэтому можем заменить ими пропуски.

# %%
df.loc[df["ponds_around3000"].isna(), "ponds_around3000"] = df[
    "ponds_around3000"
].median()

# %%
df.loc[df["parks_around3000"].isna(), "parks_around3000"] = df[
    "parks_around3000"
].median()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  float64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  float64
#  5   ceiling_height        23650 non-null  float64
#  6   floors_total          23650 non-null  float64
#  7   living_area           23214 non-null  float64
#  8   floor                 23650 non-null  float64
#  9   is_apartment          23650 non-null  object
#  10  studio                23650 non-null  object
#  11  open_plan             23650 non-null  object
#  12  kitchen_area          22843 non-null  float64
#  13  balcony               23650 non-null  float64
# ...

# %% [markdown]
# Все пропуски в датафрейме обработаны.

# %% [markdown]
# ### Проверка данных на аномалии и исправления

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0  2019-03-07T00:00:00    3.0
# 1           7.0   3350000.0        40.4  2018-12-04T00:00:00    1.0
# 2          10.0   5196000.0        56.0  2015-08-20T00:00:00    2.0
# 3           0.0  64900000.0       159.0  2015-07-24T00:00:00    3.0
# 4           2.0  10000000.0       100.0  2018-06-19T00:00:00    2.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ... balcony  \
# 0            2.70          16.0        51.00    8.0        False  ...     0.0
# 1            2.70          11.0        18.60    1.0        False  ...     2.0
# 2            2.61           5.0        34.30    4.0        False  ...     0.0
# 3            2.61          14.0       141.51    9.0        False  ...     0.0
# 4            3.03          14.0        32.00   13.0        False  ...     0.0
#
#      locality_name  airports_nearest  cityCenters_nearest parks_around3000  \
# ...

# %%
df.select_dtypes(exclude="object")[df.select_dtypes(exclude="object") < 0].count()
# Out:
# total_images           0
# last_price             0
# total_area             0
# rooms                  0
# ceiling_height         0
# floors_total           0
# living_area            0
# floor                  0
# kitchen_area           0
# balcony                0
# airports_nearest       0
# cityCenters_nearest    0
# parks_around3000       0
# parks_nearest          0
# ponds_around3000       0
# ponds_nearest          0
# days_exposition        0
# center_distance_km     0
# dtype: int64

# %% [markdown]
# Видим, что в df нет отрицательных величин.

# %%
df.select_dtypes(exclude="object")[df.select_dtypes(exclude="object") == 0].count()
# Out:
# total_images            1058
# last_price                 0
# total_area                 0
# rooms                    197
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# kitchen_area            1446
# balcony                15195
# airports_nearest           1
# cityCenters_nearest        0
# parks_around3000       15529
# parks_nearest              0
# ponds_around3000        9055
# ponds_nearest              0
# days_exposition            0
# center_distance_km      8017
# dtype: int64

# %% [markdown]
# Видно, что в столбце `rooms` присутствуют нулевые значения, хотя любая квартира должна состоять хотя бы из одной комнаты, следовательно, это аномалия.

# %%
df.loc[df["rooms"] == 0]["rooms"].count() / len(df["rooms"])
# Out:
# 0.008329809725158562

# %% [markdown]
# Получили, что доля нулевых значений в столбце `rooms` крайне мала, поэтому можем удалить соответствующие строки.

# %%
df = df.loc[df["rooms"] != 0]

# %%
df[df["rooms"] == 0]["rooms"].count()
# Out:
# 0

# %% [markdown]
# Также столбец `airports_nearest` имеет одно нулевое аномальное значение, удалим его.

# %%
df = df.loc[df["airports_nearest"] != 0]

# %%
df[df["airports_nearest"] == 0]["airports_nearest"].count()
# Out:
# 0

# %% [markdown]
# Проверим, что в столбцах булева типа только два значения.

# %%
df["is_apartment"].value_counts()
# Out:
# False      23341
# 12244.5       61
# True          50
# Name: is_apartment, dtype: int64

# %%
df["open_plan"].value_counts()
# Out:
# False      23383
# 12244.5       61
# True           8
# Name: open_plan, dtype: int64

# %%
df["studio"].value_counts()
# Out:
# False      23380
# 12244.5       61
# True          11
# Name: studio, dtype: int64

# %% [markdown]
# Аномалий в столбцах булева типа не обнаружено.

# %% [markdown]
# Проверим столбец `ceiling_height` на аномалии.

# %%
df.sort_values("ceiling_height")["ceiling_height"]
# Out:
# 22590        1.00
# 5712         1.20
# 16934        1.75
# 552          2.00
# 5850         2.00
#            ...
# 15161    12244.50
# 11796    12244.50
# 10879    12244.50
# 19861    12244.50
# 2707     12244.50
# Name: ceiling_height, Length: 23452, dtype: float64

# %%
df1 = df.loc[(df["ceiling_height"] >= 2.5) & (df["ceiling_height"] <= 4.0)]

# %%
df1.shape[0]
# Out:
# 23245

# %%
df.shape[0]
# Out:
# 23452

# %%
1 - df1.shape[0] / df.shape[0]
# Out:
# 0.008826539314344184

# %% [markdown]
# Как видим, в `ceiling_height` есть аномальные значения, но их немного, поэтому можем удалить строчки с ними.

# %%
df = df.loc[(df["ceiling_height"] >= 2.5) & (df["ceiling_height"] <= 4.0)]

# %%
df["ceiling_height"].unique()
# Out:
# array([2.7 , 2.61, 3.03, 2.5 , 2.67, 2.56, 3.05, 2.75, 2.6 , 2.9 , 2.8 ,
#        2.55, 3.  , 2.65, 3.2 , 3.25, 3.45, 2.77, 2.85, 2.64, 2.57, 3.5 ,
#        3.3 , 2.71, 4.  , 2.73, 2.84, 3.1 , 3.4 , 3.06, 2.72, 2.54, 2.51,
#        2.78, 2.76, 2.58, 3.7 , 2.52, 2.87, 2.66, 2.59, 3.6 , 2.92, 3.11,
#        3.13, 3.8 , 3.15, 3.55, 3.16, 3.62, 3.12, 2.53, 2.74, 2.96, 2.79,
#        2.95, 2.94, 3.82, 3.54, 3.53, 2.83, 3.38, 3.01, 3.65, 3.9 , 3.18,
#        3.35, 3.57, 2.62, 2.82, 3.98, 2.63, 3.83, 3.52, 3.95, 3.75, 2.88,
#        3.67, 3.87, 3.66, 3.85, 3.86, 3.24, 3.36, 3.08, 3.68, 3.07, 3.37,
#        3.09, 3.26, 3.34, 2.81, 3.44, 2.97, 3.14, 2.68, 3.22, 3.27, 2.93,
#        3.46, 3.47, 3.33, 3.63, 3.32, 2.98, 2.86, 3.17, 3.28, 3.04, 3.84,
#        3.23, 3.02, 3.21, 3.43, 3.78, 3.39, 2.69, 3.31, 3.56, 3.51, 3.93,
#        3.42, 2.99, 3.49, 2.91, 3.88, 3.29, 3.76, 3.69, 2.89, 3.58, 3.48,
#        3.59])

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось выполнить пункт 2.4 из брифа проекта
#
# Шаг 2. Предобработка данных
#
#
# __4.	Найдите и устраните редкие и выбивающиеся значения.__
#
# Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах.
# +	Если природа аномалии понятна и данные действительно искажены, то восстановите корректное значение.
# +	В противном случае удалите редкие и выбивающиеся значения.
# +	В ячейке с типом markdown опишите, какие особенности в данных вы обнаружили.
#
# __проверим какие аномалии остались__ таблица ниже

# %% [markdown]
# <div class="alert alert-info">
# Найдем и устраним редкие и выбивающиеся значения.
# </div>

# %%
(
    df[
        [
            "rooms",
            "total_area",
            "ceiling_height",
            "days_exposition",
            "last_price",
            "living_area",
            "kitchen_area",
            "floor",
            "floors_total",
        ]
    ]
    .apply(["count", "min", "max"])
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_d8778_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d8778_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d8778_row0_col0" class="data row0 col0" >23,245.00</td>
#                         <td id="T_d8778_row0_col1" class="data row0 col1" >23,245.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Совет, что считать редкостью или аномалией для нашего датасета
#
# Для примера предлагаю квартиры с 19 комнатами исключить, т.к. объект кардинально выбивается из выборки в которой по несколько тысяч квартир с 2-мя, 3-мя комнатами и только одна, две с 19-тью ..., плюс в кол-ве комнат могут быть и другие редкости
#
#
# допустим в Питере и окрестностях по состоянию на 2019 г. были или не были дома этажностью выше 30-ти этажей, а если и были, то можно ли считать их обычными объявлениями для нашего датасета
#
# Провести работу по очистке датасета от редких значений(есть и другие аномалии) в других параметрах, таблица выше в помощь
#
# И дальше на проекте мы уже работаем с очищенным датасетом

# %%
df.rooms.value_counts().to_frame()
# Out:
#       rooms
# 1.0    7977
# 2.0    7853
# 3.0    5745
# 4.0    1167
# 5.0     316
# 6.0     101
# 7.0      55
# 8.0      12
# 9.0       8
# 10.0      3
# 14.0      2
# 11.0      2
# 19.0      1
# 15.0      1
# 12.0      1
# 16.0      1

# %% [markdown]
# Видим, что в нашем датафрейме остались редкие квартиры с большим количеством комнат (больше 7), выбивающимся из общей выборки. Удалим их.

# %%
df = df[df["rooms"] < 8]

# %%
df.rooms.value_counts().to_frame()
# Out:
#      rooms
# 1.0   7977
# 2.0   7853
# 3.0   5745
# 4.0   1167
# 5.0    316
# 6.0    101
# 7.0     55

# %%
df.floors_total.value_counts().to_frame()
# Out:
#       floors_total
# 5.0           5694
# 9.0           3726
# 16.0          1350
# 12.0          1350
# 4.0           1181
# 10.0          1161
# 25.0          1043
# 6.0            893
# 17.0           814
# 3.0            653
# 7.0            576
# 14.0           543
# 18.0           494
# 24.0           445
# 8.0            384
# 2.0            375
# 15.0           362
# 23.0           344
# 19.0           332
# 22.0           283
# 20.0           267
# 13.0           231
# 11.0           199
# 27.0           162
# 21.0           155
# 26.0           121
# 1.0             26
# 35.0            22
# 28.0            21
# 36.0             2
# 29.0             1
# 60.0             1
# 52.0             1
# 34.0             1
# 33.0             1

# %% [markdown]
# Удалим выбивающиеся значения в столбце `floors_total`(больше 30).

# %%
df = df[df["floors_total"] < 31]

# %%
df.floors_total.value_counts().to_frame()
# Out:
#       floors_total
# 5.0           5694
# 9.0           3726
# 16.0          1350
# 12.0          1350
# 4.0           1181
# 10.0          1161
# 25.0          1043
# 6.0            893
# 17.0           814
# 3.0            653
# 7.0            576
# 14.0           543
# 18.0           494
# 24.0           445
# 8.0            384
# 2.0            375
# 15.0           362
# 23.0           344
# 19.0           332
# 22.0           283
# 20.0           267
# 13.0           231
# 11.0           199
# 27.0           162
# 21.0           155
# 26.0           121
# 1.0             26
# 28.0            21
# 29.0             1

# %%
df.floor.value_counts().to_frame()
# Out:
#       floor
# 2.0    3287
# 3.0    3017
# 1.0    2867
# 4.0    2759
# 5.0    2568
# 6.0    1273
# 7.0    1179
# 8.0    1067
# 9.0    1030
# 10.0    677
# 12.0    517
# 11.0    511
# 13.0    367
# 15.0    336
# 14.0    328
# 16.0    307
# 17.0    217
# 18.0    174
# 19.0    141
# 21.0    121
# 20.0    109
# 22.0    107
# 23.0     94
# 24.0     60
# 25.0     44
# 26.0     21
# 27.0      8

# %%
df.sort_values("total_area", ascending=False)["total_area"]
# Out:
# 12859    631.2
# 3117     631.0
# 15651    618.0
# 4237     517.0
# 15016    500.0
#          ...
# 19558     13.2
# 19807     13.0
# 19546     13.0
# 17961     13.0
# 19904     12.0
# Name: total_area, Length: 23186, dtype: float64

# %% [markdown]
# Удалим строчки с площадью больше 200 и меньше 9 квадратных метров, так как строки с такими значениями являются аномалиями в нашей таблице.

# %%
df = df[(df["total_area"] < 200) & (df["total_area"] > 9)]

# %%
df.sort_values("total_area", ascending=False)["total_area"]
# Out:
# 15079    199.2
# 6509     198.9
# 16656    198.1
# 10315    198.0
# 11438    198.0
#          ...
# 19558     13.2
# 19546     13.0
# 19807     13.0
# 17961     13.0
# 19904     12.0
# Name: total_area, Length: 22997, dtype: float64

# %%
df.sort_values("living_area", ascending=False)["living_area"]
# Out:
# 15079    177.288
# 2709     175.330
# 2756     174.440
# 7131     174.440
# 18320    167.320
#           ...
# 23534        NaN
# 23584        NaN
# 23587        NaN
# 23588        NaN
# 23697        NaN
# Name: living_area, Length: 22997, dtype: float64

# %% [markdown]
# <div class="alert alert-info">
# Удалим строки с площадью меньше 9 квадратных метров.
# </div>

# %%
df.sort_values("living_area", ascending=False)["living_area"].tail(20)
# Out:
# 22834   NaN
# 22839   NaN
# 22912   NaN
# 22923   NaN
# 23018   NaN
# 23060   NaN
# 23079   NaN
# 23106   NaN
# 23228   NaN
# 23238   NaN
# 23292   NaN
# 23324   NaN
# 23326   NaN
# 23423   NaN
# 23426   NaN
# 23534   NaN
# 23584   NaN
# 23587   NaN
# 23588   NaN
# 23697   NaN
# Name: living_area, dtype: float64

# %%
# check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22997 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22997 non-null  float64
#  1   last_price            22997 non-null  float64
#  2   total_area            22997 non-null  float64
#  3   first_day_exposition  22997 non-null  object
#  4   rooms                 22997 non-null  float64
#  5   ceiling_height        22997 non-null  float64
#  6   floors_total          22997 non-null  float64
#  7   living_area           22571 non-null  float64
#  8   floor                 22997 non-null  float64
#  9   is_apartment          22997 non-null  object
#  10  studio                22997 non-null  object
#  11  open_plan             22997 non-null  object
#  12  kitchen_area          22391 non-null  float64
#  13  balcony               22997 non-null  float64
# ...

# %%
df = df[(df["living_area"] > 9)]

# %%
df.sort_values("living_area", ascending=False)["living_area"]
# Out:
# 15079    177.288
# 2709     175.330
# 7131     174.440
# 2756     174.440
# 18320    167.320
#           ...
# 8086      10.000
# 21393     10.000
# 19253     10.000
# 21908      9.800
# 22473      9.100
# Name: living_area, Length: 22550, dtype: float64

# %%
# check
df.shape
# Out:
# (22550, 23)

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> слишком жесткое условие фильтрации, теряем 1/3 часть датасета
#
#         df = df[(df["living_area"] > 20)]
#
# стоит смягчить, это датасет о жилищном фонде Ленинградской области, могут быть тысячи вариантов, и довольно не редких
#
# самые редкие смотрим кодом .tail(20)
#
# __Критичный уровень очистки таблицы равен 10% от первоначального кол-ва всех записей, оптимальный 5%__

# %%
df.sort_values("kitchen_area", ascending=False)["kitchen_area"]
# Out:
# 16239    93.2
# 16797    93.0
# 10867    87.2
# 4394     77.0
# 14644    75.0
#          ...
# 23546     NaN
# 23579     NaN
# 23604     NaN
# 23655     NaN
# 23696     NaN
# Name: kitchen_area, Length: 22550, dtype: float64

# %% [markdown]
# Удалим отрицательные значения в `kitchen_area`.

# %%
df = df[(df["kitchen_area"] >= 0)]

# %%
df.sort_values("kitchen_area", ascending=False)["kitchen_area"]
# Out:
# 16239    93.2
# 16797    93.0
# 10867    87.2
# 4394     77.0
# 14644    75.0
#          ...
# 16200     0.0
# 9261      0.0
# 22288     0.0
# 12040     0.0
# 1150      0.0
# Name: kitchen_area, Length: 21945, dtype: float64

# %%
df.sort_values("ceiling_height", ascending=False)["ceiling_height"]
# Out:
# 10228    4.0
# 6269     4.0
# 13890    4.0
# 21857    4.0
# 179      4.0
#         ...
# 16715    2.5
# 4306     2.5
# 16707    2.5
# 16706    2.5
# 23698    2.5
# Name: ceiling_height, Length: 21945, dtype: float64

# %% [markdown]
# Видим, что в столбце `ceiling_height` присутствую значения меньше 2.4, что в России считается минимальной нормой, избавимся от таких значений.

# %%
df = df[df["ceiling_height"] >= 2.4]

# %%
df.sort_values("ceiling_height", ascending=False)["ceiling_height"]
# Out:
# 10228    4.0
# 6269     4.0
# 13890    4.0
# 21857    4.0
# 179      4.0
#         ...
# 16715    2.5
# 4306     2.5
# 16707    2.5
# 16706    2.5
# 23698    2.5
# Name: ceiling_height, Length: 21945, dtype: float64

# %% [markdown]
# Далее видим множество строк с двузначными значениями, скорее всего это опечатки, поэтому, поделив такие значения на 10 можно получить реалистичные значения.

# %%
arr1 = (
    df[(df["ceiling_height"] > 10) & (df["ceiling_height"] < 100)]["ceiling_height"]
    / 10
)

# %%
arr1
# Out:
# Series([], Name: ceiling_height, dtype: float64)

# %%
df.loc[
    (df["ceiling_height"] > 10) & (df["ceiling_height"] < 100), "ceiling_height"
] = arr1

# %%
df.sort_values("ceiling_height", ascending=False)["ceiling_height"]
# Out:
# 10228    4.0
# 6269     4.0
# 13890    4.0
# 21857    4.0
# 179      4.0
#         ...
# 16715    2.5
# 4306     2.5
# 16707    2.5
# 16706    2.5
# 23698    2.5
# Name: ceiling_height, Length: 21945, dtype: float64

# %% [markdown]
# Удалим квартиры с высотой потолков меньше 2.4 метра или больше 4 метров.

# %%
df = df[(df["ceiling_height"] >= 2.4) & (df["ceiling_height"] <= 4)]

# %%
df.sort_values("ceiling_height", ascending=False)["ceiling_height"]
# Out:
# 10228    4.0
# 6269     4.0
# 13890    4.0
# 21857    4.0
# 179      4.0
#         ...
# 16715    2.5
# 4306     2.5
# 16707    2.5
# 16706    2.5
# 23698    2.5
# Name: ceiling_height, Length: 21945, dtype: float64

# %% [markdown]
# Столбец `days_exposition` будет обрабатываться далее отдельно.

# %%
df.sort_values("last_price", ascending=False)["last_price"]
# Out:
# 1436     330000000.0
# 22831    289238400.0
# 17912    135000000.0
# 4996     124000000.0
# 16647    122000000.0
#             ...
# 9581        450000.0
# 16274       440000.0
# 14911       430000.0
# 17456       430000.0
# 8793         12190.0
# Name: last_price, Length: 21945, dtype: float64

# %%
df.last_price.value_counts().to_frame()
# Out:
#             last_price
# 4500000.0          328
# 3500000.0          273
# 4200000.0          251
# 4000000.0          250
# 4300000.0          247
# ...                ...
# 10430000.0           1
# 3180500.0            1
# 7297000.0            1
# 31490000.0           1
# 4386000.0            1
#
# [2616 rows x 1 columns]

# %% [markdown]
# В столбце `last_price` видим аномально маленькое значение - 12190, удалим его.

# %%
df = df[df["last_price"] >= 400000]

# %%
df.sort_values("last_price", ascending=False)["last_price"]
# Out:
# 1436     330000000.0
# 22831    289238400.0
# 17912    135000000.0
# 4996     124000000.0
# 16647    122000000.0
#             ...
# 5698        450000.0
# 9581        450000.0
# 16274       440000.0
# 17456       430000.0
# 14911       430000.0
# Name: last_price, Length: 21944, dtype: float64

# %%
(
    df[
        [
            "rooms",
            "total_area",
            "ceiling_height",
            "days_exposition",
            "last_price",
            "living_area",
            "kitchen_area",
            "floor",
            "floors_total",
        ]
    ]
    .apply(["count", "min", "max"])
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_d3755_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3755_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d3755_row0_col0" class="data row0 col0" >21,944.00</td>
#                         <td id="T_d3755_row0_col1" class="data row0 col1" >21,944.00</td>
# ...

# %% [markdown]
# В результате в датафрейме больше нет аномалий.

# %% [markdown]
# ### Изменение типов данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21944 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          21944 non-null  float64
#  1   last_price            21944 non-null  float64
#  2   total_area            21944 non-null  float64
#  3   first_day_exposition  21944 non-null  object
#  4   rooms                 21944 non-null  float64
#  5   ceiling_height        21944 non-null  float64
#  6   floors_total          21944 non-null  float64
#  7   living_area           21944 non-null  float64
#  8   floor                 21944 non-null  float64
#  9   is_apartment          21944 non-null  object
#  10  studio                21944 non-null  object
#  11  open_plan             21944 non-null  object
#  12  kitchen_area          21944 non-null  float64
#  13  balcony               21944 non-null  float64
# ...

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0  2019-03-07T00:00:00    3.0
# 1           7.0   3350000.0        40.4  2018-12-04T00:00:00    1.0
# 2          10.0   5196000.0        56.0  2015-08-20T00:00:00    2.0
# 3           0.0  64900000.0       159.0  2015-07-24T00:00:00    3.0
# 4           2.0  10000000.0       100.0  2018-06-19T00:00:00    2.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ... balcony  \
# 0            2.70          16.0        51.00    8.0        False  ...     0.0
# 1            2.70          11.0        18.60    1.0        False  ...     2.0
# 2            2.61           5.0        34.30    4.0        False  ...     0.0
# 3            2.61          14.0       141.51    9.0        False  ...     0.0
# 4            3.03          14.0        32.00   13.0        False  ...     0.0
#
#      locality_name  airports_nearest  cityCenters_nearest parks_around3000  \
# ...

# %% [markdown]
# Заменим вещественный тип данных в столбцах `balcony`, `floors_total`, `floor` на целочисленный.

# %%
df["balcony"] = df["balcony"].astype("int")

# %%
df["floors_total"] = df["floors_total"].astype("int")

# %%
df["floor"] = df["floor"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21944 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          21944 non-null  float64
#  1   last_price            21944 non-null  float64
#  2   total_area            21944 non-null  float64
#  3   first_day_exposition  21944 non-null  object
#  4   rooms                 21944 non-null  float64
#  5   ceiling_height        21944 non-null  float64
#  6   floors_total          21944 non-null  int64
#  7   living_area           21944 non-null  float64
#  8   floor                 21944 non-null  int64
#  9   is_apartment          21944 non-null  object
#  10  studio                21944 non-null  object
#  11  open_plan             21944 non-null  object
#  12  kitchen_area          21944 non-null  float64
#  13  balcony               21944 non-null  int64
# ...

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0  2019-03-07T00:00:00    3.0
# 1           7.0   3350000.0        40.4  2018-12-04T00:00:00    1.0
# 2          10.0   5196000.0        56.0  2015-08-20T00:00:00    2.0
# 3           0.0  64900000.0       159.0  2015-07-24T00:00:00    3.0
# 4           2.0  10000000.0       100.0  2018-06-19T00:00:00    2.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ... balcony  \
# 0            2.70            16        51.00      8        False  ...       0
# 1            2.70            11        18.60      1        False  ...       2
# 2            2.61             5        34.30      4        False  ...       0
# 3            2.61            14       141.51      9        False  ...       0
# 4            3.03            14        32.00     13        False  ...       0
#
#      locality_name  airports_nearest  cityCenters_nearest parks_around3000  \
# ...

# %% [markdown]
# Приведем строку в `first_day_exposition` к типу дата.

# %%
df["first_day_exposition"] = pd.to_datetime(
    df["first_day_exposition"], format="%Y-%m-%d %H:%M"
)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           7.0   3350000.0        40.4           2018-12-04    1.0
# 2          10.0   5196000.0        56.0           2015-08-20    2.0
# 3           0.0  64900000.0       159.0           2015-07-24    3.0
# 4           2.0  10000000.0       100.0           2018-06-19    2.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ... balcony  \
# 0            2.70            16        51.00      8        False  ...       0
# 1            2.70            11        18.60      1        False  ...       2
# 2            2.61             5        34.30      4        False  ...       0
# 3            2.61            14       141.51      9        False  ...       0
# 4            3.03            14        32.00     13        False  ...       0
#
#      locality_name  airports_nearest  cityCenters_nearest parks_around3000  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> тип данных изменен корректно

# %% [markdown]
# ###  Удаление дубликатов

# %% [markdown]
# Найдем количество строк-дубликатов.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не обнаружено.

# %% [markdown]
# Проверим столбец `locality_name` на наличие неявных дубликатов.

# %%
sorted(df["locality_name"].unique())
# Out:
# ['Бокситогорск',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Высоцк',
#  'Гатчина',
#  'Зеленогорск',
#  'Ивангород',
#  'Каменногорск',
#  'Кингисепп',
#  'Кириши',
#  'Кировск',
#  'Колпино',
#  'Коммунар',
#  'Красное Село',
#  'Кронштадт',
#  'Кудрово',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Луга',
#  'Любань',
#  'Мурино',
#  'Никольское',
#  'Новая Ладога',
#  'Отрадное',
#  'Павловск',
#  'Петергоф',
#  'Пикалёво',
#  'Подпорожье',
#  'Приморск',
#  'Приозерск',
#  'Пушкин',
#  'Санкт-Петербург',
#  'Светогорск',
#  'Сертолово',
#  'Сестрорецк',
#  'Сланцы',
#  'Сосновый Бор',
#  'Сясьстрой',
#  'Тихвин',
#  'Тосно',
#  'Шлиссельбург',
#  'городской поселок Большая Ижора',
#  'городской поселок Янино-1',
#  'городской посёлок Будогощь',
#  'городской посёлок Виллози',
#  'городской посёлок Лесогорский',
#  'городской посёлок Мга',
#  'городской посёлок Назия',
#  'городской посёлок Новоселье',
#  'городской посёлок Павлово',
#  'городской посёлок Рощино',
# ...

# %%
len(df["locality_name"].unique())
# Out:
# 356

# %%
len(df["locality_name"])
# Out:
# 21944

# %%
def check1(n):
    if "поселок" in n:
        return n.replace("поселок", "посёлок")
    else:
        return n

# %%
df["locality_name"] = df["locality_name"].apply(check1)

# %%
sorted(df["locality_name"].unique())
# Out:
# ['Бокситогорск',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Высоцк',
#  'Гатчина',
#  'Зеленогорск',
#  'Ивангород',
#  'Каменногорск',
#  'Кингисепп',
#  'Кириши',
#  'Кировск',
#  'Колпино',
#  'Коммунар',
#  'Красное Село',
#  'Кронштадт',
#  'Кудрово',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Луга',
#  'Любань',
#  'Мурино',
#  'Никольское',
#  'Новая Ладога',
#  'Отрадное',
#  'Павловск',
#  'Петергоф',
#  'Пикалёво',
#  'Подпорожье',
#  'Приморск',
#  'Приозерск',
#  'Пушкин',
#  'Санкт-Петербург',
#  'Светогорск',
#  'Сертолово',
#  'Сестрорецк',
#  'Сланцы',
#  'Сосновый Бор',
#  'Сясьстрой',
#  'Тихвин',
#  'Тосно',
#  'Шлиссельбург',
#  'городской посёлок Большая Ижора',
#  'городской посёлок Будогощь',
#  'городской посёлок Виллози',
#  'городской посёлок Лесогорский',
#  'городской посёлок Мга',
#  'городской посёлок Назия',
#  'городской посёлок Новоселье',
#  'городской посёлок Павлово',
#  'городской посёлок Рощино',
#  'городской посёлок Советский',
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты-посёлки удалены, больше дубликатов нет.

# %%
df.locality_name.nunique()
# Out:
# 322

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />вариант рабочий по избавлению от неявных дубликатов,
#
# можно поработать дальше, осталось не менее 20 неявных дубликатов в наимении нас. пунктов ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> принято

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Добавим в таблицу столбец `price_per_area`, в котором будет храниться цена квадратного метра.

# %%
df["price_per_area"] = df["last_price"] / df["total_area"]

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           7.0   3350000.0        40.4           2018-12-04    1.0
# 2          10.0   5196000.0        56.0           2015-08-20    2.0
# 3           0.0  64900000.0       159.0           2015-07-24    3.0
# 4           2.0  10000000.0       100.0           2018-06-19    2.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8        False  ...
# 1            2.70            11        18.60      1        False  ...
# 2            2.61             5        34.30      4        False  ...
# 3            2.61            14       141.51      9        False  ...
# 4            3.03            14        32.00     13        False  ...
#
#      locality_name airports_nearest  cityCenters_nearest  parks_around3000  \
# ...

# %% [markdown]
# Добавим столбцы `first_exposition_day_of_week`, `first_exposition_month` и `first_exposition_year`.

# %%
df["first_exposition_month"] = pd.DatetimeIndex(df["first_day_exposition"]).month

# %%
df["first_exposition_year"] = pd.DatetimeIndex(df["first_day_exposition"]).year

# %%
df["first_exposition_day_of_week"] = df["first_day_exposition"].dt.weekday

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           7.0   3350000.0        40.4           2018-12-04    1.0
# 2          10.0   5196000.0        56.0           2015-08-20    2.0
# 3           0.0  64900000.0       159.0           2015-07-24    3.0
# 4           2.0  10000000.0       100.0           2018-06-19    2.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8        False  ...
# 1            2.70            11        18.60      1        False  ...
# 2            2.61             5        34.30      4        False  ...
# 3            2.61            14       141.51      9        False  ...
# 4            3.03            14        32.00     13        False  ...
#
#   parks_around3000 parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# Надо заметить, что в днях недели считается, что 0 - понедельник, 6 - воскресенье.

# %% [markdown]
# Создадим столбец `floor_type`, в который запишем этаж квартиры.

# %%
def get_floor_type(row):
    if row["floors_total"] == row["floor"] and row["floor"] != 1:
        return "last"
    elif row["floor"] == 1:
        return "first"
    else:
        return "other"

# %%
df["floor_type"] = df.apply(get_floor_type, axis=1)

# %%
df[(df["floor"] == 1) & (df["floor_type"] == "last")]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, center_distance_km, price_per_area, first_exposition_month, first_exposition_year, first_exposition_day_of_week, floor_type]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поработать над алгоритмом функции, в результате у нас появилось несколько записей, когда первые этажи попали в категорию последних

# %%
df.groupby("floor_type")["floor_type"].count()
# Out:
# floor_type
# first     2721
# last      3145
# other    16078
# Name: floor_type, dtype: int64

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />покажи мне пожалуйста, где используется добавленные данные по отношениям площадей ... это задача из предыдущей версии задания по проекту ...
#
#         df["kitchen_total_ratio"] = df["kitchen_area"] / df["total_area"]
#         df["living_total_ratio"] = df["living_area"] / df["total_area"]

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           7.0   3350000.0        40.4           2018-12-04    1.0
# 2          10.0   5196000.0        56.0           2015-08-20    2.0
# 3           0.0  64900000.0       159.0           2015-07-24    3.0
# 4           2.0  10000000.0       100.0           2018-06-19    2.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8        False  ...
# 1            2.70            11        18.60      1        False  ...
# 2            2.61             5        34.30      4        False  ...
# 3            2.61            14       141.51      9        False  ...
# 4            3.03            14        32.00     13        False  ...
#
#   parks_nearest ponds_around3000  ponds_nearest  days_exposition  \
# 0         482.0              2.0          755.0              NaN
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение параметров объектов

# %% [markdown]
# Изучим следующие параметры:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - этаж квартиры;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего аэропорта;
# - расстояние до ближайшего парка;
# - день и месяц публикации объявления.

# %%
df2 = pd.DataFrame()

# %%
import matplotlib.pyplot as plt

# %%
df2["total_area"] = df["total_area"]

# %%
df2["last_price"] = df["last_price"]

# %%
df2["rooms"] = df["rooms"]

# %%
df2["ceiling_height"] = df["ceiling_height"]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21944 entries, 0 to 23698
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total_area      21944 non-null  float64
#  1   last_price      21944 non-null  float64
#  2   rooms           21944 non-null  float64
#  3   ceiling_height  21944 non-null  float64
# dtypes: float64(4)
# memory usage: 857.2 KB

# %%
ax = plt.subplot()

ax.hist(df2["total_area"], bins=100, range=(0, 400))
ax.set_title("Гистограмма распределения total_area")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df2["total_area"].describe()
# Out:
# count    21944.000000
# mean        58.417270
# std         26.140166
# min         13.000000
# 25%         40.200000
# 50%         52.000000
# 75%         69.000000
# max        199.200000
# Name: total_area, dtype: float64

# %%
df3 = pd.DataFrame()

# %%
df3["total_area"] = df2["total_area"]

# %%
df3.boxplot()
plt.ylim(0, 200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# Из полученной гистограммы следует, что наиболее встречающаяся площадь - чуть более 50 квадратных метров, при этом по диаграмме размаха и статистическим данным видно, что существуют выбросы, но они достаточно редки, так как из вида диаграммы можно сделать вывод, что медианное значение не стремится к длинному хвосту высоких значений. Поэтому среднее значение не сильно отличается от медианы.

# %%
df3.drop(columns=["total_area"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df["living_area"], bins=200)
ax.set_title("Гистограмма распределения living_area")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df["living_area"].describe()
# Out:
# count    21944.000000
# mean        34.568656
# std         18.310750
# min          9.100000
# 25%         19.000000
# 50%         31.000000
# 75%         43.000000
# max        177.288000
# Name: living_area, dtype: float64

# %%
df3["living_area"] = df["living_area"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видно, что чаще всего квартиры имеют живую площадь, равную примерно 30 квадратных метров. Так же, как и в случае общей площади, медиана не сильно отличается от среднего значения.

# %%
df3.drop(columns=["living_area"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df["kitchen_area"], bins=100, range=(0, 50))
ax.set_title("Гистограмма распределения kitchen_area")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df["kitchen_area"].describe()
# Out:
# count    21944.000000
# mean         9.650973
# std          5.687973
# min          0.000000
# 25%          6.700000
# 50%          9.000000
# 75%         11.400000
# max         93.200000
# Name: kitchen_area, dtype: float64

# %%
df3["kitchen_area"] = df["kitchen_area"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме видны два пика - в нуле и около 7-9 метров. Как мы предположили раннее, нулевую площадь имеют кухни в квартирах-студиях, и как видим, таких квартир достаточно много. Также стоит отметить достаточно большое стандартное отклонение, появившееся вследствие достаточно большого количества кухонь большой площади.

# %%
df3.drop(columns=["kitchen_area"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df2["last_price"], bins=300, range=(0, 100000000))
ax.set_title("Гистограмма распределения last_price")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, наглядный
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %%
df2["last_price"].describe()
# Out:
# count    2.194400e+04
# mean     6.021921e+06
# std      6.205056e+06
# min      4.300000e+05
# 25%      3.450000e+06
# 50%      4.650000e+06
# 75%      6.680000e+06
# max      3.300000e+08
# Name: last_price, dtype: float64

# %%
df3["last_price"] = df2["last_price"]

# %%
df3.dropna(how="all", axis=1)
# Out:
#        last_price
# 0      13000000.0
# 1       3350000.0
# 2       5196000.0
# 3      64900000.0
# 4      10000000.0
# ...           ...
# 23692   1350000.0
# 23693   4600000.0
# 23694   9700000.0
# 23695   3100000.0
# 23698   1350000.0
#
# [21944 rows x 1 columns]

# %%
df3.boxplot()
plt.ylim(-10000000, 100000000)
# Out:
# (-10000000.0, 100000000.0)

# %% [markdown]
# Видно, что существует достаточно много выбросов, среднеквадратичное отклонение велико, вследствие этого значительна разница между медианой и средним значением.

# %%
df3.drop(columns=["last_price"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df2["rooms"], bins=100, range=(0, 8))
ax.set_title("Гистограмма распределения rooms")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df2["rooms"].describe()
# Out:
# count    21944.000000
# mean         2.056143
# std          0.976104
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          7.000000
# Name: rooms, dtype: float64

# %%
df3["rooms"] = df2["rooms"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из гистограммы следует, что в нашей таблице больше всего одно и двух - комнатных квартир. Выбросы в виде квартир с большим количеством комнат редки, поэтому разница между средним и медианным значением мала.

# %%
df3.drop(columns=["rooms"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df2["ceiling_height"], bins=100, range=(2.3, 4))
ax.set_title("Гистограмма распределения ceiling_height")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df2["ceiling_height"].describe()
# Out:
# count    21944.000000
# mean         2.691600
# std          0.199761
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %%
df3["ceiling_height"] = df2["ceiling_height"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из гистограммы и диаграммы размаха следует, что самая частая высота потолков - 2.5-2.7 метров, что соответствует современным стандартам, при этом достаточно много квартир с потолками 3 метра в высоту, что было стандартом в прошлом. Квартиры с потолками выше этого значения редки, поэтому различие между медианой и средним несущественно.

# %%
df3.drop(columns=["ceiling_height"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df["floor"], bins=200)
ax.set_title("Гистограмма распределения floor")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df["floor"].describe()
# Out:
# count    21944.000000
# mean         5.843784
# std          4.819697
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         27.000000
# Name: floor, dtype: float64

# %%
df3["floor"] = df["floor"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# По виду гистограммы можно прийти к выводу, что больше всего продается квартир на 1-5 этажах, а квартир на этажах выше 10 крайне мало, но это и понятно, такие квартиры могут быть только в новостройках.

# %%
df3.drop(columns=["floor"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df["floor_type"], bins=3)
ax.set_title("Гистограмма распределения floor_type")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %% [markdown]
# Из гистограммы видно, что больше всего квартир на этажах выше первого и меньше последнего, что совершенно логично.

# %%
ax = plt.subplot()

ax.hist(df["floors_total"], bins=100)
ax.set_title("Гистограмма распределения floors_total")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df["floors_total"].describe()
# Out:
# count    21944.000000
# mean        10.593784
# std          6.484252
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         15.000000
# max         29.000000
# Name: floors_total, dtype: float64

# %%
df3["floors_total"] = df["floors_total"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим, что больше всего жилых зданий этажностью 5 и 9 этажей, что можно объяснить тем, что зачастую это здания постройки 19-20 века, а их в Санкт-Петербурге и его окрестностях больше всего.

# %%
df3.drop(columns=["floors_total"], axis=1, inplace=True)

# %% [markdown]
# Изучим столбец `cityCenters_nearest` только для квартир в Санкт-Петербурге, так как для дальнейшего исследования важна статистика именно этих квартир.

# %%
df2["cityCenters_nearest"] = df.query('locality_name == "Санкт-Петербург"')[
    "cityCenters_nearest"
]

# %%
ax = plt.subplot()

ax.hist(df2["cityCenters_nearest"], bins=300, range=(0, 30000))
ax.set_title("Гистограмма распределения cityCenters_nearest")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df2["cityCenters_nearest"].describe()
# Out:
# count    14556.000000
# mean     11647.866516
# std       4723.708343
# min        181.000000
# 25%       8460.000000
# 50%      12307.000000
# 75%      14942.250000
# max      29343.000000
# Name: cityCenters_nearest, dtype: float64

# %%
df3["cityCenters_nearest"] = df2["cityCenters_nearest"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# На основе гистограммы можно прийти к выводу, что почти все квартиры расположены в пределах примерно 25 километров от центра, что кажется реалистичным.

# %%
df3.drop(columns=["cityCenters_nearest"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df["airports_nearest"], bins=100, range=(0, 60000))
ax.set_title("Гистограмма распределения airports_nearest")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df["airports_nearest"].describe()
# Out:
# count    21944.000000
# mean     28361.725141
# std      11180.914554
# min       6450.000000
# 25%      20951.500000
# 50%      26756.500000
# 75%      34533.750000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
df3["airports_nearest"] = df["airports_nearest"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме виден явный пик в районе 26-28 километров, в этом промежутке находятся медиана и среднее, при этом существует достаточно большой разброс значений в удаленности от ближайшего аэропорта.

# %%
df3.drop(columns=["airports_nearest"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df["parks_nearest"], bins=100, range=(0, 1000))
ax.set_title("Гистограмма распределения parks_nearest")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df["parks_nearest"].describe()
# Out:
# count    21944.000000
# mean       468.038644
# std        200.751614
# min          1.000000
# 25%        456.000000
# 50%        456.000000
# 75%        456.000000
# max       3190.000000
# Name: parks_nearest, dtype: float64

# %%
df3["parks_nearest"] = df["parks_nearest"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме выделяется пик в районе 480 метров, что подтверждается статистическими данными и диаграммой размаха. При этом существует большой разброс значений.

# %%
df3.drop(columns=["parks_nearest"], axis=1, inplace=True)

# %%
ax = plt.subplot()

ax.hist(df["first_exposition_day_of_week"], bins=7)
ax.set_title("Гистограмма распределения first_exposition_day_of_week")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %% [markdown]
# Больше всего объявлений публикуется в будние дни, что логично.

# %%
ax = plt.subplot()

ax.hist(df["first_exposition_month"], bins=12)
ax.set_title("Гистограмма распределения first_exposition_month")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %% [markdown]
# На гистограмме видны два линейных тренда: нисходящий - с февраля до начала мая, восходящий - с конца мая до начала июня. Заметны периоды спада количества объявлений в начале и конце года.

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Осталось добавить выполнение пункта проекта
#
# Шаг 4. Проведите исследовательский анализ данных:
# 1.	Изучите следующие параметры объектов:
#     +	общая площадь;
#     +	жилая площадь;
#     +	площадь кухни;
#     +	цена объекта;
#     +	количество комнат;
#     +	высота потолков;
#     +	этаж квартиры;
#     +	тип этажа квартиры («первый», «последний», «другой»);
#     +	общее количество этажей в доме;
#     +	расстояние до центра города в метрах;
#     +	расстояние до ближайшего аэропорта;
#     +	расстояние до ближайшего парка;
#     +	день и месяц публикации объявления.
#
#
# __Постройте отдельные гистограммы для каждого из этих параметров.__ Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# ### Изучение скорости продажи квартир

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#     # example 1
#
#     #### example 2

# %% [markdown]
# Изучим столбец `days_exposition`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21944 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   total_images                  21944 non-null  float64
#  1   last_price                    21944 non-null  float64
#  2   total_area                    21944 non-null  float64
#  3   first_day_exposition          21944 non-null  datetime64[ns]
#  4   rooms                         21944 non-null  float64
#  5   ceiling_height                21944 non-null  float64
#  6   floors_total                  21944 non-null  int64
#  7   living_area                   21944 non-null  float64
#  8   floor                         21944 non-null  int64
#  9   is_apartment                  21944 non-null  object
#  10  studio                        21944 non-null  object
#  11  open_plan                     21944 non-null  object
# ...

# %%
ax = plt.subplot()

ax.hist(df["days_exposition"], bins=300, range=(0, 1200))
ax.set_title("Гистограмма распределения days_exposition")
ax.set_xlabel("Значения")
ax.set_ylabel("Частота")

plt.show()

# %%
df["days_exposition"].describe()
# Out:
# count    19057.000000
# mean       180.246419
# std        218.891662
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        230.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
df3["days_exposition"] = df["days_exposition"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из полученных графиков и данных можно сделать вывод, что существуют слишком быстрые продажи (меньше 3 дней), когда скорее всего владелец выставил объявление о продаже, а потом передумал продавать, либо слишком долгие (больше года), когда владелец после продажи забыл убрать объявление. Удалим данные аномалии, из-за которых происходит большое отличие среднего от медианы.

# %%
df = df.loc[
    ((df["days_exposition"] >= 3) & (df["days_exposition"] <= 365))
    | (df["days_exposition"].isna())
]

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />после очистки датасета в п.2.4 не стоит изменять существующий датасет, можно создавать следующие версии

# %%
df["days_exposition"].hist(bins=300, range=(0, 400))
# Out:
# <AxesSubplot:>

# %%
df["days_exposition"].describe()
# Out:
# count    16234.000000
# mean       104.836701
# std         89.326113
# min          3.000000
# 25%         37.000000
# 50%         74.000000
# 75%        154.000000
# max        364.000000
# Name: days_exposition, dtype: float64

# %%
df3["days_exposition"] = df["days_exposition"]

# %%
df3.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# После удаления аномалий, видим, что значение среднего (105 дня) стало ближе к значению медианы (74 дней).

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19121 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   total_images                  19121 non-null  float64
#  1   last_price                    19121 non-null  float64
#  2   total_area                    19121 non-null  float64
#  3   first_day_exposition          19121 non-null  datetime64[ns]
#  4   rooms                         19121 non-null  float64
#  5   ceiling_height                19121 non-null  float64
#  6   floors_total                  19121 non-null  int64
#  7   living_area                   19121 non-null  float64
#  8   floor                         19121 non-null  int64
#  9   is_apartment                  19121 non-null  object
#  10  studio                        19121 non-null  object
#  11  open_plan                     19121 non-null  object
# ...

# %% [markdown]
# ### Изучение влияния различных параметров на цену объекта

# %% [markdown]
# Выясним, какие факторы больше всего влияют на стоимость квартиры. Сначала установим зависимость цены от площади, числа комнат, удалённости от центра.

# %%
df.plot(
    x="total_area",
    y="last_price",
    kind="scatter",
    grid=True,
    xlim=(0, 200),
    ylim=(0, 100000000),
    alpha=0.3,
)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %%
df["total_area"].corr(df["last_price"])
# Out:
# 0.6408121559158182

# %% [markdown]
# Полученная диаграмма рассеяния и коэффициент корреляции Пирсона говорят о том, что связь цены и площади квартиры ближе к линейной нежели к какой-либо другой.

# %%
df.plot(
    x="living_area",
    y="last_price",
    kind="scatter",
    grid=True,
    xlim=(0, 160),
    ylim=(0, 100000000),
    alpha=0.3,
)
# Out:
# <AxesSubplot:xlabel='living_area', ylabel='last_price'>

# %%
df["living_area"].corr(df["last_price"])
# Out:
# 0.5168126334173622

# %% [markdown]
# Полученная диаграмма рассеяния и коэффициент корреляции Пирсона говорят о том, что связь цены и жилой площади квартиры близка к линейной.

# %%
df.plot(
    x="kitchen_area",
    y="last_price",
    kind="scatter",
    grid=True,
    xlim=(0.001, 60),
    ylim=(0, 100000000),
    alpha=0.3,
)
# Out:
# <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит избавиться от нулевых заглушек при расчете коэф. корреляции и строительстве графиков

# %%
df.query('kitchen_area > 0')["kitchen_area"].corr(df["last_price"])
# Out:
# 0.5004227876519474

# %% [markdown]
# Полученная диаграмма рассеяния и коэффициент корреляции Пирсона говорят о том, что связь цены и жилой площади квартиры ближе к нелинейной.

# %%
df.plot(
    x="rooms",
    y="last_price",
    kind="scatter",
    grid=True,
    ylim=(0, 100000000),
    alpha=0.2,
)
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %%
df["rooms"].corr(df["last_price"])
# Out:
# 0.366625514919031

# %% [markdown]
# Коэффициент корреляции количества комнат и цены близок к нулю, поэтому между этими параметрами существует очень слабая линейная связь. Это следует и из вида диаграммы рассеяния.

# %% [markdown]
# Найдем зависимость цены от типа этажа.

# %%
df.groupby("floor_type")["last_price"].describe()
# Out:
#               count          mean           std       min        25%  \
# floor_type
# first        2311.0  4.636395e+06  4.518552e+06  430000.0  2797000.0
# last         2707.0  5.664408e+06  7.667486e+06  430000.0  2980000.0
# other       14103.0  6.155789e+06  5.979731e+06  450000.0  3600000.0
#
#                   50%        75%          max
# floor_type
# first       3900000.0  5300000.0  135000000.0
# last        4250000.0  6292500.0  289238400.0
# other       4800000.0  6800000.0  330000000.0

# %%
df1 = df.groupby("floor_type")["last_price"].mean().to_frame()

# %%
df1["last_price"]
# Out:
# floor_type
# first    4.636395e+06
# last     5.664408e+06
# other    6.155789e+06
# Name: last_price, dtype: float64

# %%
df1.plot(kind="bar", grid=True)
# Out:
# <AxesSubplot:xlabel='floor_type'>

# %% [markdown]
# Из полученных диаграмм и статистических данных можно сделать вывод, что тип этажа влияет на цену. Наибольшее среднее и медианное значение имеют квартиры на этажах со второго до последнего, наименьшее - квартиры на первом этаже, при этом наибольшее стандартное отклонение наблюдается у квартир, расположенных на последнем этаже.

# %% [markdown]
# Изучим зависимость цены от даты размещения: дня недели, месяца и года.

# %%
df.groupby("first_exposition_day_of_week")["last_price"].describe()
# Out:
#                                count          mean           std       min  \
# first_exposition_day_of_week
# 0                             2920.0  5.929406e+06  5.056250e+06  430000.0
# 1                             3360.0  5.930955e+06  7.125032e+06  430000.0
# 2                             3161.0  5.894703e+06  7.333609e+06  450000.0
# 3                             3420.0  6.068657e+06  6.277693e+06  450000.0
# 4                             3279.0  5.818067e+06  4.975613e+06  450000.0
# 5                             1600.0  5.817843e+06  5.629298e+06  550000.0
# 6                             1381.0  5.682495e+06  4.919358e+06  470000.0
#
#                                     25%        50%        75%          max
# first_exposition_day_of_week
# 0                             3496000.0  4600000.0  6500000.0   65000000.0
# 1                             3450000.0  4650000.0  6500000.0  289238400.0
# 2                             3450000.0  4600000.0  6590000.0  330000000.0
# ...

# %%
df1 = df.groupby("first_exposition_day_of_week")["last_price"].mean().to_frame()

# %%
df1
# Out:
#                                 last_price
# first_exposition_day_of_week
# 0                             5.929406e+06
# 1                             5.930955e+06
# 2                             5.894703e+06
# 3                             6.068657e+06
# 4                             5.818067e+06
# 5                             5.817843e+06
# 6                             5.682495e+06

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='first_exposition_day_of_week'>

# %% [markdown]
# Из построенного графика следует, что наибольшее значение - в четверг, а наименьшее - в воскресенье, но в целом можно сказать, что цена квартиры не зависит от дня недели размещения, так как разница цены в разные дни недели несущественна.

# %%
df.groupby("first_exposition_month")["last_price"].describe()
# Out:
#                          count          mean           std       min  \
# first_exposition_month
# 1                       1189.0  5.734189e+06  4.775469e+06  600000.0
# 2                       2219.0  5.999972e+06  6.133173e+06  450000.0
# 3                       2080.0  5.975346e+06  7.834724e+06  550000.0
# 4                       1955.0  6.037951e+06  8.973479e+06  430000.0
# 5                        950.0  5.792227e+06  4.499427e+06  600000.0
# 6                       1376.0  5.700009e+06  5.215580e+06  430000.0
# 7                       1351.0  5.875685e+06  4.985679e+06  440000.0
# 8                       1428.0  6.100095e+06  5.651395e+06  450000.0
# 9                       1628.0  5.943788e+06  5.461674e+06  520000.0
# 10                      1730.0  5.688677e+06  5.101607e+06  600000.0
# 11                      1960.0  5.976951e+06  5.006034e+06  560000.0
# 12                      1255.0  5.793637e+06  5.722928e+06  490000.0
#
# ...

# %%
df1 = df.groupby("first_exposition_month")["last_price"].mean().to_frame()

# %%
df1
# Out:
#                           last_price
# first_exposition_month
# 1                       5.734189e+06
# 2                       5.999972e+06
# 3                       5.975346e+06
# 4                       6.037951e+06
# 5                       5.792227e+06
# 6                       5.700009e+06
# 7                       5.875685e+06
# 8                       6.100095e+06
# 9                       5.943788e+06
# 10                      5.688677e+06
# 11                      5.976951e+06
# 12                      5.793637e+06

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='first_exposition_month'>

# %% [markdown]
# Аналогично зависимости цены от дня недели публикации объявления из полученных данных можно сделать вывод, что цена не зависит от месяца размещения.

# %%
df.groupby("first_exposition_year")["last_price"].describe()
# Out:
#                         count          mean           std        min  \
# first_exposition_year
# 2014                     18.0  1.691522e+07  1.097692e+07  2300000.0
# 2015                    277.0  7.668950e+06  8.496632e+06  1200000.0
# 2016                   1652.0  6.043437e+06  5.696244e+06   600000.0
# 2017                   6790.0  5.822554e+06  5.588784e+06   450000.0
# 2018                   7785.0  5.674648e+06  5.667091e+06   430000.0
# 2019                   2599.0  6.440379e+06  8.169592e+06   430000.0
#
#                              25%         50%         75%          max
# first_exposition_year
# 2014                   8200000.0  17525000.0  23625000.0   45900000.0
# 2015                   3700000.0   5144000.0   7585000.0   86738800.0
# 2016                   3400000.0   4500000.0   6583855.0   65000000.0
# 2017                   3399000.0   4490000.0   6450000.0  124000000.0
# 2018                   3400000.0   4590000.0   6450000.0  330000000.0
# ...

# %%
df1 = df.groupby("first_exposition_year")["last_price"].mean().to_frame()

# %%
df1
# Out:
#                          last_price
# first_exposition_year
# 2014                   1.691522e+07
# 2015                   7.668950e+06
# 2016                   6.043437e+06
# 2017                   5.822554e+06
# 2018                   5.674648e+06
# 2019                   6.440379e+06

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='first_exposition_year'>

# %% [markdown]
# Из полученного графика можно сделать вывод, что заметно дороже квартиры стоили в 2014 году, а с 2015 по 2019 наблюдались небольшие колебания в цене.

# %% [markdown]
# Таким образом, приходим к выводу, что цена квартиры зависит от ее площади,этажа, на котором она  расположена, и года размещения объявления.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />отметим, что нельзя ориентироваться на 2014 год, т.к. кол-во объявлений было небольшим, а стоимость объявлений высокой, м.б. это были маркетинговые объявления в начале работы сервиса ...

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  стоит выполнить актуальный план проекта
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# __Советы по графикам:__
#
# + зависимость параметров (от площади, числа комнат, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели),
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям)

# %% [markdown]
# ### Нахождение стоимости квартир в топ-10 самых популярных населенных пунктах

# %% [markdown]
# Выберем 10 населённых пунктов с наибольшим числом объявлений и среди них выделим населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           7.0   3350000.0        40.4           2018-12-04    1.0
# 2           2.0  10000000.0       100.0           2018-06-19    2.0
# 3          10.0   2890000.0        30.4           2018-09-10    1.0
# 4           6.0   3700000.0        37.3           2017-11-02    1.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16         51.0      8        False  ...
# 1            2.70            11         18.6      1        False  ...
# 2            3.03            14         32.0     13        False  ...
# 3            2.70            12         14.4      5        False  ...
# 4            2.70            26         10.6      6        False  ...
#
#   parks_nearest ponds_around3000  ponds_nearest  days_exposition  \
# 0         482.0              2.0          755.0              NaN
# ...

# %%
df.groupby("locality_name")["locality_name"].agg(["count"]).sort_values(
    "count", ascending=False
).head(10)
# Out:
#                    count
# locality_name
# Санкт-Петербург    12647
# посёлок Мурино       423
# посёлок Шушары       377
# Всеволожск           331
# Пушкин               310
# Колпино              298
# посёлок Парголово    273
# Гатчина              255
# деревня Кудрово      222
# Выборг               193

# %%
df3 = (
    df.groupby("locality_name")["locality_name"]
    .agg(["count"])
    .sort_values("count", ascending=False)
)

# %%
list_of_cities = df3.index[0:10]

# %%
list_of_cities
# Out:
# Index(['Санкт-Петербург', 'посёлок Мурино', 'посёлок Шушары', 'Всеволожск',
#        'Пушкин', 'Колпино', 'посёлок Парголово', 'Гатчина', 'деревня Кудрово',
#        'Выборг'],
#       dtype='object', name='locality_name')

# %%
df4 = df.query("locality_name in @list_of_cities")

# %%
df5 = df4.pivot_table(
    index="locality_name", values="price_per_area", aggfunc="mean"
).sort_values("price_per_area", ascending=False)

# %%
round(df5, 2)
# Out:
#                    price_per_area
# locality_name
# Санкт-Петербург         112608.68
# Пушкин                  102622.03
# деревня Кудрово          92368.02
# посёлок Парголово        90315.87
# посёлок Мурино           85220.75
# посёлок Шушары           78680.80
# Колпино                  75070.93
# Всеволожск               69265.55
# Гатчина                  69010.55
# Выборг                   58427.31

# %%
df5.plot(kind="bar", grid=True)
# Out:
# <AxesSubplot:xlabel='locality_name'>

# %% [markdown]
# Из топ-10 самых популярных населенных пунктов наибольшую цену имеют квартиры в Санкт-Петербурге, наименьшую - в Выборге.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         Гатчина	69148.373903
#         Выборг	58383.317668

# %% [markdown]
# ### Нахождение зависимости цены объекта от расстояния до центра города

# %% [markdown]
# Выделим квартиры в Санкт-Петербурге.

# %%
df_spb = df.query('locality_name=="Санкт-Петербург"')

# %%
df_spb.reset_index(drop=True, inplace=True)

# %%
df_spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           2.0  10000000.0       100.0           2018-06-19    2.0
# 2          18.0   5400000.0        61.0           2017-02-26    3.0
# 3           5.0   5050000.0        39.6           2017-11-16    1.0
# 4          16.0   4650000.0        39.0           2017-11-18    1.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16         51.0      8        False  ...
# 1            3.03            14         32.0     13        False  ...
# 2            2.50             9         43.6      7        False  ...
# 3            2.67            12         20.3      3        False  ...
# 4            2.61            14         20.5      5        False  ...
#
#   parks_nearest ponds_around3000  ponds_nearest  days_exposition  \
# 0         482.0              2.0          755.0              NaN
# ...

# %%
df_spb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12647 entries, 0 to 12646
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   total_images                  12647 non-null  float64
#  1   last_price                    12647 non-null  float64
#  2   total_area                    12647 non-null  float64
#  3   first_day_exposition          12647 non-null  datetime64[ns]
#  4   rooms                         12647 non-null  float64
#  5   ceiling_height                12647 non-null  float64
#  6   floors_total                  12647 non-null  int64
#  7   living_area                   12647 non-null  float64
#  8   floor                         12647 non-null  int64
#  9   is_apartment                  12647 non-null  object
#  10  studio                        12647 non-null  object
#  11  open_plan                     12647 non-null  object
# ...

# %%
df_spb["center_distance_km"]
# Out:
# 0        16
# 1         8
# 2        15
# 3        14
# 4        14
#          ..
# 12642    17
# 12643    14
# 12644    16
# 12645     6
# 12646     4
# Name: center_distance_km, Length: 12647, dtype: int64

# %%
df_spb.sort_values("center_distance_km")[["cityCenters_nearest", "center_distance_km"]]
# Out:
#        cityCenters_nearest  center_distance_km
# 7363                 423.0                   0
# 1000                 287.0                   0
# 4618                 376.0                   0
# 4584                 215.0                   0
# 4109                 318.0                   0
# ...                    ...                 ...
# 12245              28018.0                  28
# 5112               28018.0                  28
# 5779               28644.0                  29
# 6962               29343.0                  29
# 9003               29263.0                  29
#
# [12647 rows x 2 columns]

# %% [markdown]
# Посчитаем среднюю цену для каждого километра.

# %%
df_1 = df_spb.pivot_table(
    index="center_distance_km", values="price_per_area", aggfunc="mean"
)

# %%
data_subcategory = df_spb.merge(df_1, on="center_distance_km", how="left")

# %%
df_spb.pivot_table(index="center_distance_km", values="price_per_area", aggfunc="mean")
# Out:
#                     price_per_area
# center_distance_km
# 0                    213836.359431
# 1                    179652.729132
# 2                    150279.141251
# 3                    120516.087129
# 4                    127610.369194
# 5                    137294.101635
# 6                    145952.006749
# 7                    149893.193166
# 8                    122953.975206
# 9                    113840.118891
# 10                   111626.566289
# 11                   107898.156893
# 12                   108020.781577
# 13                   108559.587207
# 14                   103808.220121
# 15                   104226.165394
# 16                   100295.234250
# 17                    96778.082984
# 18                    96963.791401
# 19                    99496.800795
# 20                    87262.193886
# 21                    90478.329052
# 22                    91042.607639
# 23                    89670.376281
# 24                    82705.403355
# ...

# %%
data_subcategory.sort_values("center_distance_km")
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 7363            5.0  30600000.0       162.0           2018-07-09    7.0
# 1000           18.0   9590000.0       108.0           2017-05-23    2.0
# 4618           15.0  13500000.0        98.0           2017-12-19    3.0
# 4584            7.0  10990000.0       100.0           2015-12-16    3.0
# 4109           20.0  50000000.0        93.0           2019-04-18    2.0
# ...             ...         ...         ...                  ...    ...
# 12245           0.0   5144000.0        64.0           2015-10-14    2.0
# 5112            0.0   3413000.0        43.0           2015-11-10    1.0
# 5779           10.0   4850000.0        62.0           2017-05-16    3.0
# 6962           16.0   4200000.0        56.8           2018-07-04    2.0
# 9003           20.0   4850000.0        85.8           2019-04-22    3.0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data_subcategory.rename(
    columns={"price_per_area_y": "avg_price_per_area"}, inplace=True
)

# %%
data_subcategory.sort_values("center_distance_km")
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 7363            5.0  30600000.0       162.0           2018-07-09    7.0
# 1000           18.0   9590000.0       108.0           2017-05-23    2.0
# 4618           15.0  13500000.0        98.0           2017-12-19    3.0
# 4584            7.0  10990000.0       100.0           2015-12-16    3.0
# 4109           20.0  50000000.0        93.0           2019-04-18    2.0
# ...             ...         ...         ...                  ...    ...
# 12245           0.0   5144000.0        64.0           2015-10-14    2.0
# 5112            0.0   3413000.0        43.0           2015-11-10    1.0
# 5779           10.0   4850000.0        62.0           2017-05-16    3.0
# 6962           16.0   4200000.0        56.8           2018-07-04    2.0
# 9003           20.0   4850000.0        85.8           2019-04-22    3.0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df_1 = df_spb.pivot_table(
    index="center_distance_km", values="last_price", aggfunc="mean"
)

# %%
data_subcategory_1 = data_subcategory.merge(df_1, on="center_distance_km", how="left")

# %%
data_subcategory_1.sort_values("center_distance_km")
# Out:
#        total_images  last_price_x  total_area first_day_exposition  rooms  \
# 7363            5.0    30600000.0       162.0           2018-07-09    7.0
# 1000           18.0     9590000.0       108.0           2017-05-23    2.0
# 4618           15.0    13500000.0        98.0           2017-12-19    3.0
# 4584            7.0    10990000.0       100.0           2015-12-16    3.0
# 4109           20.0    50000000.0        93.0           2019-04-18    2.0
# ...             ...           ...         ...                  ...    ...
# 12245           0.0     5144000.0        64.0           2015-10-14    2.0
# 5112            0.0     3413000.0        43.0           2015-11-10    1.0
# 5779           10.0     4850000.0        62.0           2017-05-16    3.0
# 6962           16.0     4200000.0        56.8           2018-07-04    2.0
# 9003           20.0     4850000.0        85.8           2019-04-22    3.0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df_spb.pivot_table(index="center_distance_km", values="last_price", aggfunc="mean")
# Out:
#                       last_price
# center_distance_km
# 0                   2.317490e+07
# 1                   1.854708e+07
# 2                   1.384299e+07
# 3                   1.007180e+07
# 4                   1.043359e+07
# 5                   1.142944e+07
# 6                   1.209170e+07
# 7                   1.253984e+07
# 8                   8.865381e+06
# 9                   6.939271e+06
# 10                  6.222474e+06
# 11                  6.035903e+06
# 12                  5.774078e+06
# 13                  6.075978e+06
# 14                  5.529867e+06
# 15                  5.803615e+06
# 16                  5.370318e+06
# 17                  5.178830e+06
# 18                  4.954635e+06
# 19                  5.123153e+06
# 20                  4.709444e+06
# 21                  5.304969e+06
# 22                  5.302622e+06
# 23                  4.786132e+06
# 24                  3.835417e+06
# 25                  4.233333e+06
# ...

# %%
data_subcategory_1.rename(columns={"last_price_y": "avg_last_price"}, inplace=True)

# %%
data_subcategory_1.sort_values("center_distance_km")
# Out:
#        total_images  last_price_x  total_area first_day_exposition  rooms  \
# 7363            5.0    30600000.0       162.0           2018-07-09    7.0
# 1000           18.0     9590000.0       108.0           2017-05-23    2.0
# 4618           15.0    13500000.0        98.0           2017-12-19    3.0
# 4584            7.0    10990000.0       100.0           2015-12-16    3.0
# 4109           20.0    50000000.0        93.0           2019-04-18    2.0
# ...             ...           ...         ...                  ...    ...
# 12245           0.0     5144000.0        64.0           2015-10-14    2.0
# 5112            0.0     3413000.0        43.0           2015-11-10    1.0
# 5779           10.0     4850000.0        62.0           2017-05-16    3.0
# 6962           16.0     4200000.0        56.8           2018-07-04    2.0
# 9003           20.0     4850000.0        85.8           2019-04-22    3.0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Построим графики зависимости `avg_price_per_area` и `avg_last_price` от `center_distance_km`.

# %%
data_subcategory_1.plot(
    x="center_distance_km", y="avg_price_per_area", style="o", grid=True, alpha=0.2,
)
# Out:
# <AxesSubplot:xlabel='center_distance_km'>

# %%
data_subcategory_1.plot(
    x="center_distance_km", y="avg_last_price", style="o", grid=True, alpha=0.2,
)
# Out:
# <AxesSubplot:xlabel='center_distance_km'>

# %% [markdown]
# Из полученных графиков видно, что, чем ближе к центру, тем больше дорогих квартир и тем больше разброс в стоимости квартир, при удалении от центра стоимость квартир снижается и большинство квартир находятся в одной ценовой категории.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и проанализировать зависимость цены от расстояния до центра

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В начале даннного исследования была проведена предобработка данных, в результате которой:
# 1. Были найдены и обработаны пропущенные значения в столбцах `ceiling_height`, `floors_total`, `living_area`, `is_apartment`, `kitchen_area`, `balcony`, `locality_name`, `airports_nearest`, `cityCenters_nearest`, `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest` и `days_exposition`.
# 2. Были обработаны аномалии - нулевые значения в столбце `rooms`, `airports_nearest`, некорректные значения в столбце `ceiling_heights`, слишком быстрые и долгие продажи в столбце `days_exposition`, были удалены редкие квартиры с большим количеством комнат (больше 7), квартиры в домах с этажностью больше 30, строчки с площадью больше 200 и меньше 9 квадратных метров, аномально маленькие значения в `last_price`.
# 3. Были удалены неявные дубликаты в столбце `locality_name`.

# %% [markdown]
# Далее были добавлены следующие параметры:
# 1. Цена одного квадратного метра;
# 2. День недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# 3. Месяц публикации объявления;
# 4. Год публикации объявления;
# 5. Тип этажа квартиры (значения — «первый», «последний», «другой»);
# 6. Расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).

# %% [markdown]
# Впоследствии были исследованы следующие характеристики:
# - Жилая площадь;
# - Площадь кухни;
# - Цена объекта;
# - Количество комнат;
# - Высота потолков;
# - Этаж квартиры;
# - Тип этажа квартиры («первый», «последний», «другой»);
# - Общее количество этажей в доме;
# - Расстояние до центра города в метрах;
# - Расстояние до ближайшего аэропорта;
# - Расстояние до ближайшего парка;
# - День и месяц публикации объявления.
#
# Из полученных результатов можно выделить, что самая встречаемая общая площадь - 50 квадратных метров, самые часто встречаемые квартиры имеют одну или две комнаты, самая частая высота потолков - 2.5-2.7 метров и больше всего продается квартир на 1-5 этажах.

# %% [markdown]
# В конце работы была получена зависимость стоимости квартиры в Санкт-Петербурге и соседних населённых пунктах от следующих параметров:
# 1. Площадь,
# 2. Этаж,
# 3. Года размещения объявления.
#
# Была вычислена средняя стоимость квартиры для каждого километра и былоо обнаружено, что она уменьшается при удалении от центра, при этом разброс цен на квартиры в центре значительно больше, чем на квартиры в более удаленных районах.

# %% [markdown]
# В дальнейшем можно провести исследование зависимости от различных параметров цен на квартиры, расположенные в одном районе (не только центральном).

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Оформление вывода: стоит кратко напомнить цель исследования, как мы его провели, какие параметры рассматривали, какие редкие и выбивающиеся значения убрали, какие особенности и инсайты в данных нашли (упоминаем только основные 3-5,  с приведением найденных чисел), выделяем сильные корреляционные связи на парных признаках, если есть
#
#  + можно добавить средние значения параметров,  которые были исследованы
#
# В окончательном выводе могут быть и такие предположения, что такой-то  и такой-то сегмент квартир стоит изучить в таком разрезе, своде и т.д., т.о. очертив себе план будущих исследований :)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
# + добавить исследование данных по п.1.3
# + проверить корректность заполнения пропусков синтетическими данными
# + проверить и вернуть пропуски в столбцы о скорости продаж и расстояние до центра
# + выполнить условия фильтрации аномалий и редкостей
# + добавить графики в п. 4.3
# + пересчитать скорость продаж
#
# + добавить графики в п. 4.3
# + перепроверить блоки проекта
# + дополнить итоговый вывод
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# ## Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
import seaborn as sns

# %%
data = df.copy()

# %%
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');
